# %%
import pandas as pd

# %%
flights = pd.read_csv('flights.csv')

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z
# 3      1576     5      45  2013-01-01T10:00:00Z
# 4       762     6       0  2013-01-01T11:00:00Z

# %%
flights.shape
# Out:
# (336776, 19)

# %%
#### what is the most popular destination city from NewYork?

# %%
planes = pd.read_csv('planes.csv')

# %%
airports = pd.read_csv('airports.csv')

# %%
airlines = pd.read_csv('airlines.csv')

# %%
flights.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
flights.dep_time
# Out:
# 0         517.0
# 1         533.0
# 2         542.0
# 3         544.0
# 4         554.0
#           ...
# 336771      NaN
# 336772      NaN
# 336773      NaN
# 336774      NaN
# 336775      NaN
# Name: dep_time, Length: 336776, dtype: float64

# %%
flights.dep_delay
# Out:
# 0         2.0
# 1         4.0
# 2         2.0
# 3        -1.0
# 4        -6.0
#          ...
# 336771    NaN
# 336772    NaN
# 336773    NaN
# 336774    NaN
# 336775    NaN
# Name: dep_delay, Length: 336776, dtype: float64

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
planes.columns
# Out:
# Index(['tailnum', 'year', 'type', 'manufacturer', 'model', 'engines', 'seats',
#        'speed', 'engine'],
#       dtype='object')

# %%
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
airports.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
#### what is the most popular destination city from NewYork?

# %%
#cars.ncyl.value_counts()
flights.dest.value_counts()
# Out:
# ORD    17283
# ATL    17215
# LAX    16174
# BOS    15508
# MCO    14082
#        ...
# MTJ       15
# SBN       10
# ANC        8
# LEX        1
# LGA        1
# Name: dest, Length: 105, dtype: int64

# %%
table1 = flights.groupby('dest').agg(count = ('dest','count')).sort_values(by='count',ascending=False).reset_index()
table1
# Out:
#     dest  count
# 0    ORD  17283
# 1    ATL  17215
# 2    LAX  16174
# 3    BOS  15508
# 4    MCO  14082
# ..   ...    ...
# 100  MTJ     15
# 101  SBN     10
# 102  ANC      8
# 103  LGA      1
# 104  LEX      1
#
# [105 rows x 2 columns]

# %%
### which month is the busiest of the year?

# %%
flights.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
table2 = flights.groupby('month').agg(count = ('month','count')).sort_values(by='count',ascending=False).reset_index()
table2
# Out:
#     month  count
# 0       7  29425
# 1       8  29327
# 2      10  28889
# 3       3  28834
# 4       5  28796
# 5       4  28330
# 6       6  28243
# 7      12  28135
# 8       9  27574
# 9      11  27268
# 10      1  27004
# 11      2  24951

# %%
airports.columns
# Out:
# Index(['faa', 'name', 'lat', 'lon', 'alt', 'tz', 'dst', 'tzone'], dtype='object')

# %%
pd.merge(table1,airports[['faa', 'name']],how='left',left_on='dest',right_on='faa')
# Out:
#     dest  count  faa                                name
# 0    ORD  17283  ORD                  Chicago Ohare Intl
# 1    ATL  17215  ATL     Hartsfield Jackson Atlanta Intl
# 2    LAX  16174  LAX                    Los Angeles Intl
# 3    BOS  15508  BOS  General Edward Lawrence Logan Intl
# 4    MCO  14082  MCO                        Orlando Intl
# ..   ...    ...  ...                                 ...
# 100  MTJ     15  MTJ           Montrose Regional Airport
# 101  SBN     10  SBN                     South Bend Rgnl
# 102  ANC      8  ANC          Ted Stevens Anchorage Intl
# 103  LGA      1  LGA                          La Guardia
# 104  LEX      1  LEX                          Blue Grass
#
# [105 rows x 4 columns]

# %%
### which month is the busiest of the year?

# %%
flights.month.value_counts()
# Out:
# 7     29425
# 8     29327
# 10    28889
# 3     28834
# 5     28796
# 4     28330
# 6     28243
# 12    28135
# 9     27574
# 11    27268
# 1     27004
# 2     24951
# Name: month, dtype: int64

# %%
#### which airline is the most punctual?

# %%
flights.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
flights['total_delay'] = flights['arr_delay']+flights['dep_delay']

# %%
table1 = flights.groupby('carrier').agg(mean_delay = ('total_delay','mean')).sort_values(by='mean_delay').reset_index()
table1
# Out:
#    carrier  mean_delay
# 0       AS   -4.100141
# 1       HA   -2.014620
# 2       US    5.874288
# 3       AA    8.933421
# 4       DL   10.868291
# 5       VX   14.521110
# 6       UA   15.574920
# 7       MQ   21.220114
# 8       B6   22.425521
# 9       9E   23.819244
# 10      OO   24.517241
# 11      WN   27.310777
# 12      YV   34.455882
# 13      EV   35.635360
# 14      FL   38.721890
# 15      F9   42.121880

# %%
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
pd.merge(table1,airlines,how='left')
# Out:
#    carrier  mean_delay                         name
# 0       AS   -4.100141         Alaska Airlines Inc.
# 1       HA   -2.014620       Hawaiian Airlines Inc.
# 2       US    5.874288              US Airways Inc.
# 3       AA    8.933421       American Airlines Inc.
# 4       DL   10.868291         Delta Air Lines Inc.
# 5       VX   14.521110               Virgin America
# 6       UA   15.574920        United Air Lines Inc.
# 7       MQ   21.220114                    Envoy Air
# 8       B6   22.425521              JetBlue Airways
# 9       9E   23.819244            Endeavor Air Inc.
# 10      OO   24.517241        SkyWest Airlines Inc.
# 11      WN   27.310777       Southwest Airlines Co.
# 12      YV   34.455882           Mesa Airlines Inc.
# 13      EV   35.635360     ExpressJet Airlines Inc.
# 14      FL   38.721890  AirTran Airways Corporation
# 15      F9   42.121880       Frontier Airlines Inc.

# %%
##### what destination is the longest duration

# %%
flights.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
flights.air_time.describe()
# Out:
# count    327346.000000
# mean        150.686460
# std          93.688305
# min          20.000000
# 25%          82.000000
# 50%         129.000000
# 75%         192.000000
# max         695.000000
# Name: air_time, dtype: float64

# %%
table1=flights.groupby(['origin','dest']).agg(average_air_time=('air_time','mean')).reset_index().sort_values(by='average_air_time',ascending=False)
table1
# Out:
#     origin dest  average_air_time
# 109    JFK  HNL        623.087719
# 31     EWR  HNL        612.075209
# 1      EWR  ANC        413.125000
# 146    JFK  SFO        347.403626
# 147    JFK  SJC        346.606707
# ..     ...  ...               ...
# 0      EWR  ALB         31.787081
# 132    JFK  PHL         30.836872
# 59     EWR  PHL         28.666667
# 5      EWR  BDL         25.466019
# 40     EWR  LGA               NaN
#
# [224 rows x 3 columns]

# %%
airports.columns
# Out:
# Index(['faa', 'name', 'lat', 'lon', 'alt', 'tz', 'dst', 'tzone'], dtype='object')

# %%
pd.merge(table1,airports[['faa','name']],how='left',left_on='dest',right_on='faa')
# Out:
#     origin dest  average_air_time  faa                           name
# 0      JFK  HNL        623.087719  HNL                  Honolulu Intl
# 1      EWR  HNL        612.075209  HNL                  Honolulu Intl
# 2      EWR  ANC        413.125000  ANC     Ted Stevens Anchorage Intl
# 3      JFK  SFO        347.403626  SFO             San Francisco Intl
# 4      JFK  SJC        346.606707  SJC  Norman Y Mineta San Jose Intl
# ..     ...  ...               ...  ...                            ...
# 219    EWR  ALB         31.787081  ALB                    Albany Intl
# 220    JFK  PHL         30.836872  PHL              Philadelphia Intl
# 221    EWR  PHL         28.666667  PHL              Philadelphia Intl
# 222    EWR  BDL         25.466019  BDL                   Bradley Intl
# 223    EWR  LGA               NaN  LGA                     La Guardia
#
# [224 rows x 5 columns]

# %%
#### what airline is the worst in terms of delays

# %%
### which airline has the highest capacity of seats?

# %%
flights.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z
# 3      1576     5      45  2013-01-01T10:00:00Z
# 4       762     6       0  2013-01-01T11:00:00Z

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
carrier_tailnum = flights[['carrier','tailnum']].drop_duplicates()
carrier_tailnum
# Out:
#        carrier tailnum
# 0           UA  N14228
# 1           UA  N24211
# 2           AA  N619AA
# 3           B6  N804JB
# 4           DL  N668DN
# ...        ...     ...
# 327436      OO  N766SK
# 329041      OO  N772SK
# 330033      OO  N776SK
# 331007      OO  N785SK
# 334259      AS  N557AS
#
# [4067 rows x 2 columns]

# %%
pd.merge(carrier_tailnum,planes[['tailnum','seats']],how='left').groupby('carrier').agg(total_seats=('seats','sum')).sort_values(by='total_seats',ascending=False)
# Out:
#          total_seats
# carrier
# UA          116252.0
# DL          115715.0
# WN           82700.0
# US           57821.0
# AA           29309.0
# B6           27148.0
# EV           19525.0
# 9E           13685.0
# AS           13465.0
# FL           13451.0
# VX            8967.0
# HA            5278.0
# YV            5127.0
# F9            3612.0
# OO            2210.0
# MQ              34.0

# %%
### which airplane model is the highest in use and from which manufacturer?

# %%
airplanes_use = flights.groupby('tailnum').agg(count=('tailnum','count')).reset_index()
airplanes_use
# Out:
#      tailnum  count
# 0     D942DN      4
# 1     N0EGMQ    371
# 2     N10156    153
# 3     N102UW     48
# 4     N103US     46
# ...      ...    ...
# 4038  N997DL     63
# 4039  N998AT     26
# 4040  N998DL     77
# 4041  N999DN     61
# 4042  N9EAMQ    248
#
# [4043 rows x 2 columns]

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
pd.merge(planes[['tailnum','manufacturer','model']],airplanes_use,how='left').groupby(['model','manufacturer']).agg(total_flights=('count','sum')).sort_values(by='total_flights',ascending=False)
# Out:
#                                   total_flights
# model           manufacturer
# A320-232        AIRBUS                    31278
# EMB-145LR       EMBRAER                   28027
# ERJ 190-100 IGW EMBRAER                   23716
# A320-232        AIRBUS INDUSTRIE          14553
# EMB-145XR       EMBRAER                   14051
# ...                                         ...
# 737-3T5         BOEING                        2
# 737-3A4         BOEING                        1
# A330-323        AIRBUS                        1
# A330-223        AIRBUS INDUSTRIE              1
# 747-451         BOEING                        1
#
# [147 rows x 1 columns]

# %%
planes[['tailnum','manufacturer','model']]
# Out:
#      tailnum                   manufacturer      model
# 0     N10156                        EMBRAER  EMB-145XR
# 1     N102UW               AIRBUS INDUSTRIE   A320-214
# 2     N103US               AIRBUS INDUSTRIE   A320-214
# 3     N104UW               AIRBUS INDUSTRIE   A320-214
# 4     N10575                        EMBRAER  EMB-145LR
# ...      ...                            ...        ...
# 3317  N997AT                         BOEING    717-200
# 3318  N997DL  MCDONNELL DOUGLAS AIRCRAFT CO      MD-88
# 3319  N998AT                         BOEING    717-200
# 3320  N998DL  MCDONNELL DOUGLAS CORPORATION      MD-88
# 3321  N999DN  MCDONNELL DOUGLAS CORPORATION      MD-88
#
# [3322 rows x 3 columns]

# %%
airplanes_use
# Out:
#      tailnum  count
# 0     D942DN      4
# 1     N0EGMQ    371
# 2     N10156    153
# 3     N102UW     48
# 4     N103US     46
# ...      ...    ...
# 4038  N997DL     63
# 4039  N998AT     26
# 4040  N998DL     77
# 4041  N999DN     61
# 4042  N9EAMQ    248
#
# [4043 rows x 2 columns]
